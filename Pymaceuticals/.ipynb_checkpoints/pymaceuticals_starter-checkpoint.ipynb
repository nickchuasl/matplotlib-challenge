# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# * There are roughly equal proportion of gender of mice used when conducting the experiment.
#
# * Capomulin and Ramicane has the highest number of testing on mice ranging from 50 to 100 more testing.
#
# * Based on the comparison of the four drug regimen of Capomulin, Ramicane, Infubinol and Ceftamin, it seems that Ramicane and Capomulin has the best effect on tumor volume. The reason for this is beacuse of significantly lower median, upper and lower quartile in the tumor volume in comparison with the other two drugs.
#
# * The analysis also shows that weight and average tumor volume has a relatively strong positive relationship for mice treated with Capomulin. In other words, the higher the weight, the greater the average tumor volume.

# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem
import random
import string
from scipy import stats

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# Checking the number of mice.
length_mouse_metadata = len(mouse_metadata['Mouse ID'].unique())
length_study_results = len(study_results['Mouse ID'].unique())
print(f'The number of unique mouse in the mouse metadata file is {length_mouse_metadata}.')
print(f'The number of unique mouse in the study results file is {length_study_results}.')
# Out:
# The number of unique mouse in the mouse metadata file is 249.
# The number of unique mouse in the study results file is 249.

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
# Optional: Get all the data for the duplicate mouse ID. 
grouped_study_results = study_results.groupby(['Mouse ID','Timepoint']).count()
grouped_study_results.loc[grouped_study_results['Tumor Volume (mm3)']>1]
# Out:
#                     Tumor Volume (mm3)  Metastatic Sites
# Mouse ID Timepoint
# g989     0                           2                 2
#          5                           2                 2
#          10                          2                 2
#          15                          2                 2
#          20                          2                 2

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_study_results = study_results.loc[study_results['Mouse ID'] != 'g989']
cleaned_mouse_metadata = mouse_metadata.loc[mouse_metadata['Mouse ID'] != 'g989']

# %%
# Combine the data into a single dataset
merged_df = pd.merge(cleaned_mouse_metadata,cleaned_study_results, on="Mouse ID", how = "outer")
# Display the data table for preview
merged_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1875     z969     Naftisol  Male           9          30         25
# 1876     z969     Naftisol  Male           9          30         30
# 1877     z969     Naftisol  Male           9          30         35
# 1878     z969     Naftisol  Male           9          30         40
# 1879     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1875           63.145652                 2
# 1876           65.841013                 3
# 1877           69.176246                 4
# 1878           70.314904                 4
# 1879           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
# Checking the number of mice in the clean DataFrame.
length_merged_df = len(merged_df['Mouse ID'].unique())
length_cleaned_study_results = len(cleaned_study_results['Mouse ID'].unique())
length_cleaned_mouse_metadata = len(cleaned_mouse_metadata['Mouse ID'].unique())
print(f'The number of mice in the merged DataFrame is {length_merged_df}.')
print(f'The number of mice in the cleaned study result file is {length_cleaned_study_results}.')
print(f'The number of mice in the cleaned mouse metadata file is {length_cleaned_mouse_metadata}.')
# Out:
# The number of mice in the merged DataFrame is 248.
# The number of mice in the cleaned study result file is 248.
# The number of mice in the cleaned mouse metadata file is 248.

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
#Group data by Drug Regimen and focusing on Tumor Volume only
grouped_drug_regimen = merged_df.groupby(merged_df['Drug Regimen'])
tumor_data = grouped_drug_regimen['Tumor Volume (mm3)']

#Finding the mean for Tumor Volume (mm3)
mean_tumor = round(tumor_data.mean(),2)

#Finding the median for Tumor Volume (mm3)
median_tumor = round(tumor_data.median(),2)

#Finding the variance for Tumor Volume (mm3)
variance_tumor = round(tumor_data.var(ddof=1),2)

#standard deviation
sd_tumor = round(tumor_data.std(ddof=1),2)

#SEM 
std_error_tumor = round(tumor_data.sem(ddof=1),2)

# This method is the most straighforward, creating multiple series and putting them all together at the end.
summary_stats_tumor = pd.DataFrame([mean_tumor,median_tumor,variance_tumor,sd_tumor,std_error_tumor]).transpose()
summary_stats_tumor.columns.values[0] = 'Mean of Tumor Volume (mm3)'
summary_stats_tumor.columns.values[1] = 'Median of Tumor Volume (mm3)'
summary_stats_tumor.columns.values[2] = 'Variance of Tumor Volume (mm3)'
summary_stats_tumor.columns.values[3] = 'Std Deviation of Tumor Volume (mm3)'
summary_stats_tumor.columns.values[4] = 'SEM of Tumor Volume (mm3)'
summary_stats_tumor
# Out:
#               Mean of Tumor Volume (mm3)  Median of Tumor Volume (mm3)  \
# Drug Regimen
# Capomulin                          40.68                         41.56
# Ceftamin                           52.59                         51.78
# Infubinol                          52.88                         51.82
# Ketapril                           55.24                         53.70
# Naftisol                           54.33                         52.51
# Placebo                            54.03                         52.29
# Propriva                           52.32                         50.45
# Ramicane                           40.22                         40.67
# Stelasyn                           54.23                         52.43
# Zoniferol                          53.24                         51.82
#
#               Variance of Tumor Volume (mm3)  \
# Drug Regimen
# Capomulin                              24.95
# Ceftamin                               39.29
# Infubinol                              43.13
# Ketapril                               68.55
# Naftisol                               66.17
# Placebo                                61.17
# Propriva                               43.85
# Ramicane                               23.49
# Stelasyn                               59.45
# Zoniferol                              48.53
#
#               Std Deviation of Tumor Volume (mm3)  SEM of Tumor Volume (mm3)
# Drug Regimen
# Capomulin                                    4.99                       0.33
# Ceftamin                                     6.27                       0.47
# Infubinol                                    6.57                       0.49
# Ketapril                                     8.28                       0.60
# Naftisol                                     8.13                       0.60
# Placebo                                      7.82                       0.58
# Propriva                                     6.62                       0.54
# Ramicane                                     4.85                       0.32
# Stelasyn                                     7.71                       0.57
# Zoniferol                                    6.97                       0.52

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method produces everything in a single groupby function
tumor_data_gb = grouped_drug_regimen['Tumor Volume (mm3)']
tumor_data_gb.describe()
round(tumor_data_gb.agg(["mean","median","var","std","sem"]),2)
# Out:
#                mean  median    var   std   sem
# Drug Regimen
# Capomulin     40.68   41.56  24.95  4.99  0.33
# Ceftamin      52.59   51.78  39.29  6.27  0.47
# Infubinol     52.88   51.82  43.13  6.57  0.49
# Ketapril      55.24   53.70  68.55  8.28  0.60
# Naftisol      54.33   52.51  66.17  8.13  0.60
# Placebo       54.03   52.29  61.17  7.82  0.58
# Propriva      52.32   50.45  43.85  6.62  0.54
# Ramicane      40.22   40.67  23.49  4.85  0.32
# Stelasyn      54.23   52.43  59.45  7.71  0.57
# Zoniferol     53.24   51.82  48.53  6.97  0.52

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
#Create a new variable to manipulate the data
new_merged_df = merged_df[['Drug Regimen','Mouse ID']]

#Group data by Drug Regimen
grouped_merged = new_merged_df.groupby(['Drug Regimen'])
bar_plot_data= grouped_merged.count()

#Create a list of the drugs and use it as the x-axis
x_axis = merged_df['Drug Regimen'].unique().tolist()
sorted_x_axis = sorted(x_axis)
sorted_x_axis

#Plot the graph
plt.figure(figsize=(6,9))
plt.bar(sorted_x_axis,bar_plot_data['Mouse ID'], align='center')
plt.title('Total number of mice for each drug')
plt.xlabel('Drug Regimen')
plt.xticks(rotation=45)
plt.ylabel('Count of mice')
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0, 0.5, 'Count of mice')

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
#Create a new variable to manipulate the data
new_merged_df = merged_df[['Drug Regimen','Mouse ID']]

#Group data by Drug Regimen
grouped_merged = new_merged_df.groupby(['Drug Regimen'])

#Ensure by converting the count to numeric type
bar_plot_data['Mouse ID']= pd.to_numeric(grouped_merged['Mouse ID'].count())

#Plot the graph
bar_plot_pandas = bar_plot_data.plot(kind="bar", figsize = (6,9.5),title = 'Total number of mice for each drug',legend = False, rot=45)
bar_plot_pandas.set_xlabel('Drug Regimen')
bar_plot_pandas.set_ylabel('Count of mice')
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0, 0.5, 'Count of mice')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
#Create a blank canvas for plotting
fig = plt.figure()
ax = plt.axes()

#Generate data to plot
sizes = merged_df.value_counts('Sex').tolist()

#Generate the labels
labels = merged_df['Sex'].unique().tolist()

#Plot the graph
plt.pie(sizes, labels = labels, autopct ="%1.1f%%")
plt.axis("equal")
plt.title('Distribution of the gender (male or female) in the study')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Distribution of the gender (male or female) in the study')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
#Generate data to plot
new= pd.DataFrame(merged_df['Sex'].value_counts())

#Plot the graph
pie_plot_pandas = new.plot.pie(y= 'Sex',autopct ="%1.1f%%", title = 'Distribution of the gender (male or female) in the study', legend = False, xlabel=False)
pie_plot_pandas.set_ylabel('')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, '')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Obtained data for the following drugs: Capomulin, Ramicane, Infubinol, and Ceftamin
filter_merged_Capomulin = merged_df.loc[merged_df['Drug Regimen']=='Capomulin']
filter_merged_Ramicane = merged_df.loc[merged_df['Drug Regimen']=='Ramicane']
filter_merged_Infubinol = merged_df.loc[merged_df['Drug Regimen']=='Infubinol']
filter_merged_Ceftamin = merged_df.loc[merged_df['Drug Regimen']=='Ceftamin']

#Combined all the data of the drugs together

filter_merged_df= pd.concat([filter_merged_Capomulin,filter_merged_Ramicane,filter_merged_Infubinol,filter_merged_Ceftamin])

# Start by getting the last (greatest) timepoint for each mouse
filter_MouseID = filter_merged_df.groupby('Mouse ID')
max_timepoint= pd.DataFrame(filter_MouseID['Timepoint'].max())

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
final_tumor_volume = filter_merged_df.merge(max_timepoint, how ='inner', left_on=['Mouse ID','Timepoint'], right_on = ['Mouse ID','Timepoint'] )
final_tumor_volume
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      s185    Capomulin  Female           3          17         45
# 1      x401    Capomulin  Female          16          15         45
# 2      m601    Capomulin    Male          22          17         45
# 3      f966    Capomulin    Male          16          17         20
# 4      u364    Capomulin    Male          18          17         45
# ..      ...          ...     ...         ...         ...        ...
# 95     x226     Ceftamin    Male          23          28          0
# 96     x581     Ceftamin  Female          19          28         45
# 97     x822     Ceftamin    Male           3          29         45
# 98     y769     Ceftamin  Female           6          27         45
# 99     y865     Ceftamin    Male          23          26         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 0            23.343598                 1
# 1            28.484033                 0
# 2            28.430964                 1
# 3            30.485985                 0
# 4            31.023923                 3
# ..                 ...               ...
# 95           45.000000                 0
# 96           64.634949                 3
# 97           61.386660                 3
# 98           68.594745                 4
# 99           64.729837                 3
#
# [100 rows x 8 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
list_drugs = final_tumor_volume['Drug Regimen'].unique().tolist()

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

#Loop through each of the four drugs(Capomulin, Ramicane, Infubinol, and Ceftamin) to obtain a summary statistics
#Calculation is based on final data taken on individual mouse - hence difference in the calculation of median from this and the above
for drug_name in list_drugs:
    tumor_volume= final_tumor_volume.loc[final_tumor_volume['Drug Regimen']== drug_name]

    quartiles = tumor_volume['Tumor Volume (mm3)'].quantile([0.25,0.5,0.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq

    print(f"The lower quartile of mouse treated with {drug_name} is: {round(lowerq,2)}")
    print(f"The upper quartile of mouse treated with {drug_name}  is: {round(upperq,2)}")
    print(f"The interquartile range of mouse treated with {drug_name} is: {round(iqr,2)}")
    print(f"The the median of mouse treated with {drug_name} is: {round(quartiles[0.5],2)} ")

    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f"Values below {round(lower_bound,2)} could be outliers for mouse treated with {drug_name}.")
    print(f"Values above {round(upper_bound,2)} could be outliers for mouse treated with {drug_name}.")
    
    outlier_df = tumor_volume.loc[(tumor_volume['Tumor Volume (mm3)']<lower_bound)| (tumor_volume['Tumor Volume (mm3)']>upper_bound)]
    
    if outlier_df.empty:
        print(f"No potential outliers found for {drug_name}.")
        
    else:
        print(f'Potential outliers for {drug_name}:')
        display(outlier_df.head())
    print('\n')
# Out:
# The lower quartile of mouse treated with Capomulin is: 32.38
# The upper quartile of mouse treated with Capomulin  is: 40.16
# The interquartile range of mouse treated with Capomulin is: 7.78
# The the median of mouse treated with Capomulin is: 38.13
# Values below 20.7 could be outliers for mouse treated with Capomulin.
# Values above 51.83 could be outliers for mouse treated with Capomulin.
# No potential outliers found for Capomulin.
#
#
# The lower quartile of mouse treated with Ramicane is: 31.56
# The upper quartile of mouse treated with Ramicane  is: 40.66
# The interquartile range of mouse treated with Ramicane is: 9.1
# The the median of mouse treated with Ramicane is: 36.56
# Values below 17.91 could be outliers for mouse treated with Ramicane.
# Values above 54.31 could be outliers for mouse treated with Ramicane.
# No potential outliers found for Ramicane.
#
#
# The lower quartile of mouse treated with Infubinol is: 54.05
# The upper quartile of mouse treated with Infubinol  is: 65.53
# The interquartile range of mouse treated with Infubinol is: 11.48
# The the median of mouse treated with Infubinol is: 60.17
# Values below 36.83 could be outliers for mouse treated with Infubinol.
# Values above 82.74 could be outliers for mouse treated with Infubinol.
# Potential outliers for Infubinol:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 55     c326    Infubinol  Female          18          25          5
#
#     Tumor Volume (mm3)  Metastatic Sites
# 55           36.321346                 0
# The lower quartile of mouse treated with Ceftamin is: 48.72
# The upper quartile of mouse treated with Ceftamin  is: 64.3
# The interquartile range of mouse treated with Ceftamin is: 15.58
# The the median of mouse treated with Ceftamin is: 59.85
# Values below 25.36 could be outliers for mouse treated with Ceftamin.
# Values above 87.67 could be outliers for mouse treated with Ceftamin.
# No potential outliers found for Ceftamin.

# %%
#Create a platform to plot the graph
fig1, ax1 = plt.subplots()
ax1.set_ylim(20, 90)

#Filtering on focused individual drugs
drug1= final_tumor_volume.loc[final_tumor_volume['Drug Regimen']== 'Capomulin']
drug2= final_tumor_volume.loc[final_tumor_volume['Drug Regimen']== 'Ramicane']
drug3= final_tumor_volume.loc[final_tumor_volume['Drug Regimen']== 'Infubinol']
drug4= final_tumor_volume.loc[final_tumor_volume['Drug Regimen']== 'Ceftamin']

#Data to use to plot the graph
data1 = drug1['Tumor Volume (mm3)']
data2 = drug2['Tumor Volume (mm3)']
data3 = drug3['Tumor Volume (mm3)']
data4 = drug4['Tumor Volume (mm3)']
all_data = [data1,data2,data3,data4]

#Plotting the graph
ax1.boxplot(all_data,sym='ro')

#Creating aesthetics of the graph
x_axis = range(1,len(list_drugs)+1)
tick_drug = [value for value in x_axis]
plt.xticks(tick_drug, list_drugs)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axis.XTick at 0x1f1bbab1dc0>,
#   <matplotlib.axis.XTick at 0x1f1bbab1d90>,
#   <matplotlib.axis.XTick at 0x1f1bbad86a0>,
#   <matplotlib.axis.XTick at 0x1f1bcaedc40>],
#  [Text(1, 0, 'Capomulin'),
#   Text(2, 0, 'Ramicane'),
#   Text(3, 0, 'Infubinol'),
#   Text(4, 0, 'Ceftamin')])

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

#Find list of mice that were treated with Capomulin
capomulin_mice = merged_df.loc[merged_df['Drug Regimen']== 'Capomulin']
list_capomulin_mice = capomulin_mice['Mouse ID'].unique().tolist()
n = random.randint(0,len(list_capomulin_mice)+1)
timepoint_capomulin_mice = capomulin_mice.groupby('Mouse ID')['Timepoint'].apply(list).tolist()
tumorSize_capomulin_mice = capomulin_mice.groupby('Mouse ID')['Tumor Volume (mm3)'].apply(list).tolist()


#Data for plotting chart
x_axis= timepoint_capomulin_mice[n]
points = tumorSize_capomulin_mice[n]
mouse_id = list_capomulin_mice[n]
fig2, ax2 = plt.subplots()
plt.plot(x_axis,points)

#Creating aesthetics of the graph
plt.title(f'Timepoint vs Tumor Volume for Mouse ID: {mouse_id}')
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume (mm3)')
plt.xticks(np.arange(0, max(x_axis), step=5))
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axis.XTick at 0x1f1bcb12fd0>,
#   <matplotlib.axis.XTick at 0x1f1bcb12fa0>,
#   <matplotlib.axis.XTick at 0x1f1bcb0db20>,
#   <matplotlib.axis.XTick at 0x1f1bcb37c70>,
#   <matplotlib.axis.XTick at 0x1f1bcb421c0>,
#   <matplotlib.axis.XTick at 0x1f1bcb426d0>,
#   <matplotlib.axis.XTick at 0x1f1bcb42be0>,
#   <matplotlib.axis.XTick at 0x1f1bcb47130>,
#   <matplotlib.axis.XTick at 0x1f1bcb42760>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
#Filtering data to be used
capomulin_mice2 = merged_df.loc[merged_df['Drug Regimen']== 'Capomulin']
weight_tumorVol_capomulin = (capomulin_mice2.groupby('Mouse ID').mean())[['Weight (g)','Tumor Volume (mm3)']]

#Create a platform for graph to be plotted and plotting the graph 
fig3, ax3 = plt.subplots()
plt.scatter(weight_tumorVol_capomulin['Weight (g)'],weight_tumorVol_capomulin['Tumor Volume (mm3)'], facecolors = 'red', edgecolors = 'black')

#Creating aesthetics of the graph
plt.title('Weight vs Average Tumor Volume for Capomulin treated mice')
plt.xlabel('Weight of mice (g)')
plt.ylabel('Average Tumor Volume(mm3)')

#Create the linear regression model 
wt_slope, wt_int, wt_r, wt_p, wt_std_err = stats.linregress(weight_tumorVol_capomulin['Weight (g)'],weight_tumorVol_capomulin['Tumor Volume (mm3)'])
wt_fit = wt_slope * weight_tumorVol_capomulin['Weight (g)'] + wt_int
plt.plot(weight_tumorVol_capomulin['Weight (g)'],wt_fit,"g--")
line_eq = "y = " + str(round(wt_slope,2)) + "x + " + str(round(wt_int,2))
plt.annotate(line_eq,(16,36),fontsize=15,color="green")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(16, 36, 'y = 0.95x + 21.55')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
print(f"The correlation coefficient between the weight of mice and average tumor volume in mm3 is {round(st.pearsonr(weight_tumorVol_capomulin['Weight (g)'],weight_tumorVol_capomulin['Tumor Volume (mm3)'])[0],2)}.")
# Out:
# The correlation coefficient between the weight of mice and average tumor volume in mm3 is 0.84.
